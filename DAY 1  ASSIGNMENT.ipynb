# %%
a=int(input("Enter the number 1="))
b=int(input("Enter the  number 2="))
sub=a-b
multi=a*b
div=a/b
print("Subration=",sub)
print("Miltiplication=",multi)
print("Divide=",div)
# Out:
# Enter the number 1=15
# Enter the  number 2=12
# Subration= 3
# Miltiplication= 180
# Divide= 1.25
